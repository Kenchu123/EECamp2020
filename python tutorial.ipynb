# %% [markdown]
# ![%E6%88%AA%E5%9C%96%202020-08-01%20%E4%B8%8B%E5%8D%883.59.22.png](attachment:%E6%88%AA%E5%9C%96%202020-08-01%20%E4%B8%8B%E5%8D%883.59.22.png)

# %% [markdown]
# ## Python Introduction

# %% [markdown]
# ### print(): 把括弧內的值印出到螢幕上

# %%
print(87)
print('Hello World')

# %% [markdown]
# ### 變數可以想成是一個箱子，用來儲存一些資料。assignment(賦值)，也就是把一個值丟給一個變數。

# %%
x = 3
y = 2.5
print(x, y)

# %%
x = 3
y = 2.5
x = y
print(x, y)

# %%
# playground

# %% [markdown]
# ### String formatting: 讓使用者可以只利用改變變數的方式去改變輸出的字串。

# %%
my_name = "John"
my_age = 18
# before version 3.5
print("My name is", my_name + ", my age is", my_age)
print("My name is %s, my age is %d" % (my_name, my_age))
print("My name is {}, my age is {}".format(my_name, my_age))

# %%
my_name = "John"
my_age = 18
# after version 3.6
print(f"My name is {my_name}, my age is {my_age}")

# %%
# playground

# %% [markdown]
# ## 數值運算

# %%
x = 3
x += 2
# 等價於 x = x + 2
print(x)

# %%
import math
a = math.sqrt(25) # square root
print(a)
b = math.log10(100)
print(b)
print(math.pi)

# %%
# playground

# %% [markdown]
# ## 練習一：交換變數

# %% [markdown]
# 將兩個變數x, y的值交換
#
#
# 例如：
# 原本 x = 3, y = 6
# 目標 x = 6, y = 3
#
# Hint: 利用一個新的變數

# %%
x = 3
y = 6

### TODO:

###

print(f"x = {x}")
print(f"y = {y}")

# %% [markdown]
# ## 邏輯運算

# %%
print((5 > 3) and (7 > 8))
print((5 > 3) or (7 > 8))
print(not (5 > 3) )

# %%
# playground

# %% [markdown]
# ## If - else

# %%
num = -1
if num > 0:
    print("Positive")
else:
    if num == 0:
        print("Zero")
    else:
        print("Negative")

# %%
money = 20

if money > 80:
    print("You buy spaghetti for lunch.")
elif money > 40:
    print("You buy a bread for lunch")
else:
    print("You can buy nothing!!!")

# %%
# playground

# %% [markdown]
# ### random: 一個用來產生隨機數的模組
# ### random.randint(a, b): 產生一個變數x，a <= x <= b

# %%
import random
x = random.randint(0, 100)

print(x)

# %%
# playground

# %% [markdown]
# ## 練習二：練習 if - elif - else

# %% [markdown]
# 給定一個變數 x，判斷是否中獎
#
# 1. 如果 x 小於50，則沒有中獎
# 2. 如果 x 介於 60 ~ 80 之間，則贏得二獎
# 3. 如果 x 為83、89、97，則贏得頭獎
# 4. 如果 x 不屬於以上情況，則贏得三獎

# %%
import random

x = random.randint(0, 100)
print(f'x = {x}')

### TODO: 

###

# %% [markdown]
# ## List

# %% [markdown]
# ### Index out of range:

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[0])
print(fruits[2])
print(fruits[3])

# %% [markdown]
# ### len(): list 的長度

# %%
fruits = ["apple", "banana", "cherry"]
print(len(fruits))

# %% [markdown]
# ### append(): 在list後面新增一個元素

# %%
fruits = []   # 一個空的list
fruits.append("apple")
print(fruits)

fruits.append("banana")
print(fruits)

fruits.append("cherry")
print(fruits)

# %% [markdown]
# ### insert(n, val): 在index n的地方插入val

# %%
fruits = ["apple"]   
print(fruits)

fruits.insert(0, "banana")
print(fruits)

fruits.insert(1, "cherry")
print(fruits)

# %% [markdown]
# ### 更改list裡面的元素

# %%
fruits = ["apple", "banana", "cherry"]

fruits[0] = "grape"
fruits[1] = "kiwi"
print(fruits)

# %% [markdown]
# ### pop(n): 刪除index n的元素

# %%
fruits = ["grape", "kiwi", "cherry"]

fruits.pop(0) # 刪掉index == 0的元素
print(fruits)

fruits.pop()  # 刪掉最後一個元素
print(fruits)

# %%
# playground

# %% [markdown]
# ## 練習三：練習list的操作

# %% [markdown]
# ### str.join(list): 用來把list裡面的用str連起來

# %%
l = ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
print(''.join(l))

# %%
camp = ["N", "A", "T", "U", "R", "E"]

### TODO:

###
result = ''.join(camp)
print(f'result = {result}')

# %% [markdown]
# ## Loop 迴圈

# %% [markdown]
# ### While loop

# %%
x = 0
while x < 5:    # 當x>=5時，會跳出迴圈
    print(x)    # 每次執行print這個動作
    x += 1     # 並且x每次+1

# %%
x = 0
while True:      # 條件永遠成立，就是一直執行
    print(x)     # 每次執行print這個動作
    x += 1       # 並且x每次+1
    if x >= 5:   # 跳出條件加在這
        break    # break表示跳出迴圈

# %%
# playground

# %% [markdown]
# ### For loop

# %%
A = [0, 1, 2, 3, 4]  # A是一個list
for i in A:
    print(i)

# %%
for i in range(5):
    print(i)         # 一樣執行print的動作

# %%
# playground

# %% [markdown]
# ## 練習四：從1加到100

# %%
s = 0

### TODO:

### 

print(f'sum = {s}')

# %% [markdown]
# ## Function

# %%
import math

a = math.sqrt(25) / math.sqrt(4)
b = [sum([1, 2]), len("1234")]
print(a)
print(b)

# %%
def summation(num_list):
    result = 0
    for number in num_list:
        result += number
    return result

a = summation([1, 2, 3])
print(a)

# %%
# playground

# %% [markdown]
# ## 練習五：實作一個換零錢的function

# %% [markdown]
# Hint1: 零錢只有50、10、5、1。
#
# Hint2: 利用 // 以及 %

# %% [markdown]
# ### input(): 可以讓使用者輸入想要的值, 括弧內的字串為用來告訴使用者的文字

# %%
num = input("Please enter a number: ")
print(num)

# %%
def convert(N):
    num_50 = 0
    num_10 = 0
    num_5 = 0
    num_1 = 0

    ### TODO:

    ###

    print(f"50: {num_50}")
    print(f"10: {num_10}")
    print(f"5: {num_5}")
    print(f"1: {num_1}")

n = input("Please enter a number: ")
convert(int(n))

# %% [markdown]
# ## Array

# %%
import numpy as np

List1 = [1, 2, 3]
# 這是一個list

Array1 = np.array(List1)
# 這是一個array
print(Array1)
print(type(Array1))

# %%
import numpy as np
L1 = [1, 2, 3]
L2 = [4, 5, 6]
print(L1 + L2)
print(L1*2)

A1 = np.array(L1)
A2 = np.array(L2)
print(A1 + A2) 
print(A1*2)

# %%
import numpy as np
L1 = [[1, 2, 3], [4, 5, 6]]
A1 = np.array(L1)
print(A1)

# %% [markdown]
# ## 邊緣偵測

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

img = mpimg.imread('eecamp.jpg') 
# img would be a numpy array

h, w, c = img.shape # (height,width,color)
 

#----------------------convert to gray scale----------------------------
print('RBG to gray scale...')
gray = np.ones(img.shape) # new array for gray scale

for i in range(h):
    for j in range(w):
        ### TODO:

        ### 
        gray[i, j] = np.array([Y, Y, Y])
#-----------------------------------------------------------------------
plt.imshow(gray)
plt.axis('off')
plt.show()
plt.savefig('gray.png')

#-----------------------prewiit edge detector---------------------------
print('start to prewiit...')
result = np.ones(img.shape) * 255 # new array for prewiit 

for i in range(1, h - 1):
    for j in range(1, w - 1):
        ### TODO:

        ###
        result[i,j] = np.array([G, G, G])
#------------------------------------------------------------------------

#--------------------- show the image------------------------------------
plt.imshow(result)
plt.axis('off')
plt.show()

plt.savefig('result.png') # save the image

# %% [markdown]
# ## Answer

# %% [markdown]
# ### ex1:

# %%
x = 3
y = 6

x, y = y, x

print(f"x = {x}")
print(f"y = {y}")

# %% [markdown]
# ### ex2:

# %%
import random

x = random.randint(0, 100)
print(f'x = {x}')

if x < 50:
    print("You lose!")
elif 60 < x < 80:
    print("You won the second prize!!")
elif x == 83 or x == 89 or x == 97:
    print("You won the first prize!!!")
else:
    print("You won the third prize!")

# %% [markdown]
# ### ex3:

# %%
camp = ["N", "A", "T", "U", "R", "E"]

camp.pop(4)
camp.pop(1)
camp.append("E")

result = ''.join(camp)
print(f'result = {result}')

# %% [markdown]
# ### ex4:

# %%
# while loop
a, i = 0, 0
while i <= 100:
    a += i
    i += 1
print(a)

# %%
# for loop
a = 0
for i in range(100):
    a += (i+1)
print(a)

# %% [markdown]
# ### ex5:

# %%
def convert(N):
    num_50 = 0
    num_10 = 0
    num_5 = 0
    num_1 = 0

    num_50 = N // 50
    N = N % 50

    num_10 = N // 10
    N = N % 10

    num_5 = N // 5
    N = N % 5

    num_1 = N // 1
    N = N % 1
    
    print(f"50: {num_50}")
    print(f"10: {num_10}")
    print(f"5: {num_5}")
    print(f"1: {num_1}")
    
n = input("Please enter a number: ")
convert(int(n))

# %% [markdown]
# ### ex6:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

img = mpimg.imread('eecamp.jpg') 
# img would be a numpy array

h, w, c = img.shape # (height,width,color)
 

#----------------------convert to gray scale----------------------------
print('RBG to gray scale...')
gray = np.ones(img.shape) # new array for gray scale

for i in range(h):
    for j in range(w):
        ### TODO:
        Y = (0.3 * img[i, j, 0] + 0.59 * img[i, j, 1] + 0.11 * img[i, j, 2]) / 255
        ### 
        gray[i, j] = np.array([Y, Y, Y])
#-----------------------------------------------------------------------
plt.imshow(gray)
plt.axis('off')
plt.show()
plt.savefig('gray.png')

#-----------------------prewiit edge detector---------------------------
print('start to prewiit...')
result = np.ones(img.shape) * 255 # new array for prewiit 

for i in range(1, h - 1):
    for j in range(1, w - 1):
        ### TODO:
        Gx = -gray[i - 1, j - 1, 0] - gray[i, j - 1, 0] - gray[i + 1,j - 1, 0] + gray[i - 1,j + 1, 0] + gray[i,j + 1, 0] + gray[i + 1,j + 1, 0]
        Gy = -gray[i - 1, j - 1, 0] - gray[i - 1, j, 0] - gray[i - 1, j + 1,0] + gray[i + 1, j - 1, 0] + gray[i + 1, j, 0] + gray[i + 1, j + 1, 0]
        G = (np.sqrt(Gx ** 2 + Gy ** 2))
        if G > 1:
            G = 1
        ###
        result[i,j] = np.array([G, G, G])
#------------------------------------------------------------------------

#--------------------- show the image------------------------------------
plt.imshow(result)
plt.axis('off')
plt.show()

plt.savefig('result.png') # save the image
